# %%
import pandas as pd
import pickle

# %%
df = pd.read_pickle('data/book_data.pkl')

# %%
df.columns
# Out:
# Index(['image_url', 'book_title', 'book_authors', 'book_rating',
#        'book_rating_count', 'book_review_count', 'book_desc', 'genres',
#        'processed_text', 'Womens',
#        ...
#        'College', 'Relationships', 'Mixed Martial Arts', 'France', 'Economics',
#        'Unfinished', 'Ancient', 'Futuristic', 'German Literature',
#        'most_similar'],
#       dtype='object', length=316)

# %%
df[['image_url', 'book_title', 'book_authors', 'book_rating',
       'book_rating_count', 'book_review_count', 'book_desc', 'genres','most_similar']]
# Out:
#                                                image_url  \
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 26100  https://images-na.ssl-images-amazon.com/images...
# 26101  https://images-na.ssl-images-amazon.com/images...
# 26102  https://images-na.ssl-images-amazon.com/images...
# 26103  https://images-na.ssl-images-amazon.com/images...
# 26105  https://images-na.ssl-images-amazon.com/images...
#
#                                      book_title    book_authors  book_rating  \
# 0                         To Kill a Mockingbird      Harper Lee         4.26
# 1      Harry Potter and the Philosopher’s Stone    J.K. Rowling         4.47
# ...

# %%
df[10:]
# Out:
#                                                image_url  \
# 10     https://images-na.ssl-images-amazon.com/images...
# 11     https://images-na.ssl-images-amazon.com/images...
# 12     https://images-na.ssl-images-amazon.com/images...
# 13     https://images-na.ssl-images-amazon.com/images...
# 14     https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 26100  https://images-na.ssl-images-amazon.com/images...
# 26101  https://images-na.ssl-images-amazon.com/images...
# 26102  https://images-na.ssl-images-amazon.com/images...
# 26103  https://images-na.ssl-images-amazon.com/images...
# 26105  https://images-na.ssl-images-amazon.com/images...
#
#                      book_title         book_authors  book_rating  \
# 10               The Book Thief         Markus Zusak         4.39
# 11                    Jane Eyre     Charlotte Brontë         4.15
# 12     The Chronicles of Narnia           C.S. Lewis         4.27
# ...
